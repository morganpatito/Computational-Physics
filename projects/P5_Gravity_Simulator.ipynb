# %% [markdown]
# <a href="https://colab.research.google.com/github/dchappell2/Computational-Physics/blob/main/projects/P5_Gravity_Simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # P5. Gravity Simulator
#
# Write a gravity simulation program in Python where an arbitrary number of objects with specified masses, positions and initial velocities are given. Simulate the evolution of this system over time and create a plot showing the path of how the objects move. Use the simulation to solve the three body problem, where a moon orbits a planet that orbits a star. Is this system stable? Do you think this simulation is an accurate predictor of the dynamics of a true gravitational system? What happens when you adjust the masses, initial positions and/or initial velocities?
